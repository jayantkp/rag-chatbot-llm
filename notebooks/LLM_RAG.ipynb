# %%
# !pip install -r /content/drive/MyDrive/LLM_RAG_Bot/requirements.txt

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# !streamlit run /content/drive/LLM_RAG_Bot/app.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
